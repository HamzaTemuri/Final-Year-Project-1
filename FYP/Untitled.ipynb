# %%
import os
import pydicom
import cv2
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9e900220da71> in <module>
#       1 import os
# ----> 2 import pydicom
#       3 import cv2
#       4 import matplotlib.pyplot as plt
#       5 from PIL import Image
#
# ModuleNotFoundError: No module named 'pydicom'

# %%
path = r"C:\Users\OSama JamIL\Desktop\Final Year Project\T1_TSE_SAG_320_0003"

# %%
read_all = os.listdir(path)

# %%
print(read_all)
# Out:
# ['.ipynb_checkpoints', 'T1_TSE_SAG__0001_001.ima', 'T1_TSE_SAG__0001_002.ima', 'T1_TSE_SAG__0001_003.ima', 'T1_TSE_SAG__0001_004.ima', 'T1_TSE_SAG__0001_005.ima', 'T1_TSE_SAG__0001_006.ima', 'T1_TSE_SAG__0001_007.ima', 'T1_TSE_SAG__0001_008.ima', 'T1_TSE_SAG__0001_009.ima', 'T1_TSE_SAG__0001_010.ima', 'T1_TSE_SAG__0001_011.ima', 'T1_TSE_SAG__0001_012.ima', 'T1_TSE_SAG__0001_013.ima', 'T1_TSE_SAG__0001_014.ima', 'T1_TSE_SAG__0001_015.ima', 'Task1.ipynb']

# %%
ds = pydicom.dcmread(read_all[8])

# %%
plt.imshow(ds.pixel_array,cmap=plt.cm.bone)

# %%
import numpy as np 
import pydicom as dicom 
#ds = dicom.read_file(path_dcm) 
plt.imshow(np.invert(ds.pixel_array), cmap =plt.cm.bone)

# %%
ds.pixel_array.shape
# Out:
# (320, 320)

# %%
norm = (ds.pixel_array - np.min(ds.pixel_array)) / (np.max(ds.pixel_array) - np.min(ds.pixel_array))

# %%
plt.imshow(norm,cmap=plt.cm.bone)

# %%
norm
# Out:
# array([[0.02781137, 0.01813785, 0.01571947, ..., 0.        , 0.        ,
#         0.        ],
#        [0.03506651, 0.00483676, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.06166868, 0.12696493, 0.14631197, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.00725514, 0.03264813, 0.03385732, ..., 0.        , 0.        ,
#         0.        ],
#        [0.00483676, 0.00604595, 0.00483676, ..., 0.        , 0.        ,
#         0.        ],
#        [0.00725514, 0.00604595, 0.00846433, ..., 0.        , 0.        ,
#         0.        ]])

# %%
ds.pixel_array
# Out:
# array([[ 23,  15,  13, ...,   0,   0,   0],
#        [ 29,   4,   0, ...,   0,   0,   0],
#        [ 51, 105, 121, ...,   0,   0,   0],
#        ...,
#        [  6,  27,  28, ...,   0,   0,   0],
#        [  4,   5,   4, ...,   0,   0,   0],
#        [  6,   5,   7, ...,   0,   0,   0]], dtype=uint16)

# %%
norm = cv2.normalize(ds.pixel_array, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)

# %%
norm
# Out:
# array([[0.02781137, 0.01813785, 0.01571947, ..., 0.        , 0.        ,
#         0.        ],
#        [0.03506651, 0.00483676, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.06166868, 0.12696494, 0.14631197, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.00725514, 0.03264813, 0.03385732, ..., 0.        , 0.        ,
#         0.        ],
#        [0.00483676, 0.00604595, 0.00483676, ..., 0.        , 0.        ,
#         0.        ],
#        [0.00725514, 0.00604595, 0.00846433, ..., 0.        , 0.        ,
#         0.        ]], dtype=float32)

# %%
sizes = (320,320)

# %%
im = plt.imshow(ds.pixel_array,cmap=plt.cm.bone)
Image.thumbnail(size)
im.save("thumbnail_%s_%s" % (image, "_".join(size)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-32278f289243> in <module>
#       1 im = plt.imshow(ds.pixel_array,cmap=plt.cm.bone)
# ----> 2 Image.thumbnail(size)
#       3 im.save("thumbnail_%s_%s" % (image, "_".join(size)))
#
# AttributeError: module 'PIL.Image' has no attribute 'thumbnail'
